# %%
import pandas as pd

# %%
citiesdf= pd.read_csv('outputciudades.csv')

# %%
citiesdf
# Out:
#      Unnamed: 0                       City Country  Latitude  Longitude  \
# 0             0                     Luanda      AO     -8.83      13.24
# 1             1                    Ayabaca      PE     -4.64     -79.72
# 2             2                    Qaanaaq      GL     77.48     -69.36
# 3             3                     Hasaki      JP     35.73     140.83
# 4             4                  Hithadhoo      MV     -0.60      73.08
# 5             5               Punta Arenas      CL    -53.16     -70.91
# 6             6                     Touros      BR     -5.20     -35.46
# 7             7                       Chuy      UY    -33.69     -53.46
# 8             8                     Atuona      PF     -9.80    -139.03
# 9             9              Williams Lake      CA     52.13    -122.14
# 10           10                  Busselton      AU    -33.64     115.35
# 11           11                     Hobart      AU    -42.88     147.33
# ...

# %%
citiesdf.drop(["Unnamed: 0"], axis=1)
# Out:
#                           City Country  Latitude  Longitude  Temperature  \
# 0                       Luanda      AO     -8.83      13.24       298.15
# 1                      Ayabaca      PE     -4.64     -79.72       303.30
# 2                      Qaanaaq      GL     77.48     -69.36       278.50
# 3                       Hasaki      JP     35.73     140.83       289.90
# 4                    Hithadhoo      MV     -0.60      73.08       302.40
# 5                 Punta Arenas      CL    -53.16     -70.91       276.08
# 6                       Touros      BR     -5.20     -35.46       298.15
# 7                         Chuy      UY    -33.69     -53.46       286.90
# 8                       Atuona      PF     -9.80    -139.03       300.00
# 9                Williams Lake      CA     52.13    -122.14       287.15
# 10                   Busselton      AU    -33.64     115.35       282.20
# 11                      Hobart      AU    -42.88     147.33       282.04
# ...

# %%
citiesdf
# Out:
#      Unnamed: 0                       City Country  Latitude  Longitude  \
# 0             0                     Luanda      AO     -8.83      13.24
# 1             1                    Ayabaca      PE     -4.64     -79.72
# 2             2                    Qaanaaq      GL     77.48     -69.36
# 3             3                     Hasaki      JP     35.73     140.83
# 4             4                  Hithadhoo      MV     -0.60      73.08
# 5             5               Punta Arenas      CL    -53.16     -70.91
# 6             6                     Touros      BR     -5.20     -35.46
# 7             7                       Chuy      UY    -33.69     -53.46
# 8             8                     Atuona      PF     -9.80    -139.03
# 9             9              Williams Lake      CA     52.13    -122.14
# 10           10                  Busselton      AU    -33.64     115.35
# 11           11                     Hobart      AU    -42.88     147.33
# ...

# %%
html_table = citiesdf.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Humidity</th>\n      <th>Cloud</th>\n      <th>Winter_Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Luanda</td>\n      <td>AO</td>\n      <td>-8.83</td>\n      <td>13.24</td>\n      <td>298.15</td>\n      <td>73</td>\n      <td>51</td>\n      <td>2.60</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Ayabaca</td>\n      <td>PE</td>\n      <td>-4.64</td>\n      <td>-79.72</td>\n      <td>303.30</td>\n      <td>35</td>\n      <td>0</td>\n      <td>3.98</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Qaanaaq</td>\n      <td>GL</td>\n      <td>77.48</td>\n      <td>-69.36</td>\n      <td>278.50</td>\n      <td>71</td>\n      
# ...

# %%
citiesdf.to_html('HTMLtable.html')
